# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../Classes')

import Periodicity
import MolecularDynamics
import Potentials

from importlib import reload
reload(Periodicity)
reload(MolecularDynamics)
reload(Potentials)
#reload(Optimisation)
from Periodicity import *
from MolecularDynamics   import *
from Potentials import *

from matplotlib.animation import FuncAnimation

# %%
from .Classes import Periodicity
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from .Classes import Periodicity
#
# ImportError: attempted relative import with no known parent package

# %%
PS = PeriodicSystem(LennardJones(), pos = [1,2])
print(PS)

print(PS.copy())
# Out:
# <Periodicity.PeriodicSystem object at 0x0000023CD97A94C0>
# <Periodicity.PeriodicSystem object at 0x0000023CD97AA090>

# %%
positions = [[1,1], [1,0], [2,0], [0,2], [0,1]]

Cluster = AtomicCluster(calc = LennardJones(), pos = positions)

fig, ax = plt.subplots()

Cluster.draw(ax, size = 1000)

ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)
ax.set_aspect('equal')

relax(Cluster, steps = 100)

fig, ax = plt.subplots()

Cluster.draw(ax, size = 1000)

ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)
ax.set_aspect('equal')
