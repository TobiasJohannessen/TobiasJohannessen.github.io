# %%
from importlib import reload
import cpclasses
reload(cpclasses)
from cpclasses import *

# %%
Cluster = AtomicCluster(calc = LennardJones(),pos = [[1,2], [2,2]])

fig, ax = plt.subplots()

Cluster.draw(ax)

# %%
PS = PeriodicSystem(LennardJones(), pos = [1,2])
print(PS)

print(PS.copy())

# %%
positions = [[1,1], [1,0], [2,0], [0,2], [0,1]]

Cluster = AtomicCluster(calc = LennardJones(), pos = positions)

fig, ax = plt.subplots()

Cluster.draw(ax, size = 1000)

ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)
ax.set_aspect('equal')

relax(Cluster, steps = 100)

fig, ax = plt.subplots()

Cluster.draw(ax, size = 1000)

ax.set_xlim(-1, 3)
ax.set_ylim(-1, 3)
ax.set_aspect('equal')
